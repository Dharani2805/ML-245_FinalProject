# %% [markdown]
# ### IMPORT LIBRARIES

# %%
from pathlib import Path 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
import warnings
warnings.filterwarnings("ignore")

# %%
DATA_PATH = Path("data")

# %%
df=pd.read_csv("credit_train.csv")

# %%
df
# Out:
#                                      Loan ID  \
# 0       14dd8831-6af5-400b-83ec-68e61888a048
# 1       4771cc26-131a-45db-b5aa-537ea4ba5342
# 2       4eed4e6a-aa2f-4c91-8651-ce984ee8fb26
# 3       77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a
# 4       d4062e70-befa-4995-8643-a0de73938182
# ...                                      ...
# 100509                                   NaN
# 100510                                   NaN
# 100511                                   NaN
# 100512                                   NaN
# 100513                                   NaN
#
#                                  Customer ID Loan Status  Current Loan Amount  \
# 0       981165ec-3274-42f5-a3b4-d104041a9ca9  Fully Paid             445412.0
# 1       2de017a3-2e01-49cb-a581-08169e83be29  Fully Paid             262328.0
# 2       5efb2b2b-bf11-4dfd-a572-3761a2694725  Fully Paid           99999999.0
# 3       e777faab-98ae-45af-9a86-7ce5b33b1011  Fully Paid             347666.0
# 4       81536ad9-5ccf-4eb8-befb-47a4d608658e  Fully Paid             176220.0
# ...                                      ...         ...                  ...
# 100509                                   NaN         NaN                  NaN
# 100510                                   NaN         NaN                  NaN
# 100511                                   NaN         NaN                  NaN
# 100512                                   NaN         NaN                  NaN
# 100513                                   NaN         NaN                  NaN
#
#               Term  Credit Score  Annual Income Years in current job  \
# 0       Short Term         709.0      1167493.0              8 years
# 1       Short Term           NaN            NaN            10+ years
# 2       Short Term         741.0      2231892.0              8 years
# 3        Long Term         721.0       806949.0              3 years
# 4       Short Term           NaN            NaN              5 years
# ...            ...           ...            ...                  ...
# 100509         NaN           NaN            NaN                  NaN
# 100510         NaN           NaN            NaN                  NaN
# 100511         NaN           NaN            NaN                  NaN
# 100512         NaN           NaN            NaN                  NaN
# 100513         NaN           NaN            NaN                  NaN
#
#        Home Ownership             Purpose  Monthly Debt  \
# 0       Home Mortgage   Home Improvements       5214.74
# 1       Home Mortgage  Debt Consolidation      33295.98
# 2            Own Home  Debt Consolidation      29200.53
# 3            Own Home  Debt Consolidation       8741.90
# 4                Rent  Debt Consolidation      20639.70
# ...               ...                 ...           ...
# 100509            NaN                 NaN           NaN
# 100510            NaN                 NaN           NaN
# 100511            NaN                 NaN           NaN
# 100512            NaN                 NaN           NaN
# 100513            NaN                 NaN           NaN
#
#         Years of Credit History  Months since last delinquent  \
# 0                          17.2                           NaN
# 1                          21.1                           8.0
# 2                          14.9                          29.0
# 3                          12.0                           NaN
# 4                           6.1                           NaN
# ...                         ...                           ...
# 100509                      NaN                           NaN
# 100510                      NaN                           NaN
# 100511                      NaN                           NaN
# 100512                      NaN                           NaN
# 100513                      NaN                           NaN
#
#         Number of Open Accounts  Number of Credit Problems  \
# 0                           6.0                        1.0
# 1                          35.0                        0.0
# 2                          18.0                        1.0
# 3                           9.0                        0.0
# 4                          15.0                        0.0
# ...                         ...                        ...
# 100509                      NaN                        NaN
# 100510                      NaN                        NaN
# 100511                      NaN                        NaN
# 100512                      NaN                        NaN
# 100513                      NaN                        NaN
#
#         Current Credit Balance  Maximum Open Credit  Bankruptcies  Tax Liens
# 0                     228190.0             416746.0           1.0        0.0
# 1                     229976.0             850784.0           0.0        0.0
# 2                     297996.0             750090.0           0.0        0.0
# 3                     256329.0             386958.0           0.0        0.0
# 4                     253460.0             427174.0           0.0        0.0
# ...                        ...                  ...           ...        ...
# 100509                     NaN                  NaN           NaN        NaN
# 100510                     NaN                  NaN           NaN        NaN
# 100511                     NaN                  NaN           NaN        NaN
# 100512                     NaN                  NaN           NaN        NaN
# 100513                     NaN                  NaN           NaN        NaN
#
# [100514 rows x 19 columns]

# %%
# Number of Records
print(f"Number of rows in the dataset:{df.shape[0]}")
print(f"Number of columns in the dataset:{df.shape[1]}")
# Out:
# Number of rows in the dataset:100514
# Number of columns in the dataset:19

# %%
df.replace('na', np.nan, inplace = True) 
df.replace('null', np.nan, inplace = True) 
df.replace('NA', np.nan, inplace = True) 
df.replace('NULL', np.nan, inplace = True) 
df.replace('Null', np.nan, inplace = True)  
df.replace('NaN', np.nan, inplace = True)

# %%
new_df_filter = df.dropna(axis = 'index', how = 'any')
new_df_filter
# Out:
#                                     Loan ID  \
# 2      4eed4e6a-aa2f-4c91-8651-ce984ee8fb26
# 6      273581de-85d8-4332-81a5-19b04ce68666
# 8      8af915d9-9e91-44a0-b5a2-564a45c12089
# 10     32c2e48f-1ba8-45e0-a530-9a6622c18d9c
# 12     403d7235-0284-4bb6-919a-09402fecbf7b
# ...                                     ...
# 99990  686017b3-dc24-4f8a-af92-0bd077452d3d
# 99993  79b81158-5d55-4766-8ad6-ebcd683f7d59
# 99994  8506a4e9-af7d-47d2-a1bf-7ea2c41858f0
# 99996  06eba04f-58fc-424a-b666-ed72aa008900
# 99997  e1cb4050-eff5-4bdb-a1b0-aabd3f7eaac7
#
#                                 Customer ID Loan Status  Current Loan Amount  \
# 2      5efb2b2b-bf11-4dfd-a572-3761a2694725  Fully Paid           99999999.0
# 6      90a75dde-34d5-419c-90dc-1e58b04b3e35  Fully Paid             217646.0
# 8      af534dea-d27e-4fd6-9de8-efaa52a78ec0  Fully Paid             548746.0
# 10     0de7bcdb-ebf4-4608-ba39-05f083f855b6  Fully Paid           99999999.0
# 12     11581f68-de3c-49d8-80d9-22268ebb323b  Fully Paid           99999999.0
# ...                                     ...         ...                  ...
# 99990  1a583add-21ba-410f-9c42-757c4ed19322  Fully Paid           99999999.0
# 99993  e45e8dc4-05ad-4efe-92cc-784a6d5ef61a  Fully Paid              44484.0
# 99994  be67200e-1ef1-4b63-86a6-2bf27d3c704d  Fully Paid             210584.0
# 99996  77f2252a-b7d1-4b07-a746-1202a8304290  Fully Paid           99999999.0
# 99997  2ced5f10-bd60-4a11-9134-cadce4e7b0a3  Fully Paid             103136.0
#
#              Term  Credit Score  Annual Income Years in current job  \
# 2      Short Term         741.0      2231892.0              8 years
# 6      Short Term         730.0      1184194.0             < 1 year
# 8      Short Term         678.0      2559110.0              2 years
# 10     Short Term         728.0       714628.0              3 years
# 12     Short Term         740.0       776188.0             < 1 year
# ...           ...           ...            ...                  ...
# 99990  Short Term         742.0      1190046.0             < 1 year
# 99993  Short Term         717.0      1152426.0            10+ years
# 99994  Short Term         719.0       783389.0               1 year
# 99996  Short Term         732.0      1289416.0               1 year
# 99997  Short Term         742.0      1150545.0              6 years
#
#       Home Ownership             Purpose  Monthly Debt  \
# 2           Own Home  Debt Consolidation      29200.53
# 6      Home Mortgage  Debt Consolidation      10855.08
# 8               Rent  Debt Consolidation      18660.28
# 10              Rent  Debt Consolidation      11851.06
# 12          Own Home  Debt Consolidation      11578.22
# ...              ...                 ...           ...
# 99990           Rent               other      11969.81
# 99993  Home Mortgage      small_business       6280.64
# 99994  Home Mortgage               Other       3727.61
# 99996           Rent  Debt Consolidation      13109.05
# 99997           Rent  Debt Consolidation       7315.57
#
#        Years of Credit History  Months since last delinquent  \
# 2                         14.9                          29.0
# 6                         19.6                          10.0
# 8                         22.6                          33.0
# 10                        16.0                          76.0
# 12                         8.5                          25.0
# ...                        ...                           ...
# 99990                     20.1                          16.0
# 99993                     21.0                          12.0
# 99994                     17.4                          18.0
# 99996                      9.4                          21.0
# 99997                     18.8                          18.0
#
#        Number of Open Accounts  Number of Credit Problems  \
# 2                         18.0                        1.0
# 6                         13.0                        1.0
# 8                          4.0                        0.0
# 10                        16.0                        0.0
# 12                         6.0                        0.0
# ...                        ...                        ...
# 99990                      9.0                        0.0
# 99993                      6.0                        0.0
# 99994                      6.0                        0.0
# 99996                     22.0                        0.0
# 99997                     12.0                        1.0
#
#        Current Credit Balance  Maximum Open Credit  Bankruptcies  Tax Liens
# 2                    297996.0             750090.0           0.0        0.0
# 6                    122170.0             272052.0           1.0        0.0
# 8                    437171.0             555038.0           0.0        0.0
# 10                   203965.0             289784.0           0.0        0.0
# 12                   134083.0             220220.0           0.0        0.0
# ...                       ...                  ...           ...        ...
# 99990                 37392.0             134442.0           0.0        0.0
# 99993                961932.0                  0.0           0.0        0.0
# 99994                   456.0             259160.0           0.0        0.0
# 99996                153045.0             509234.0           0.0        0.0
# 99997                109554.0             537548.0           1.0        0.0
#
# [36423 rows x 19 columns]

# %%
new_df_filter.isnull()
# Out:
#        Loan ID  Customer ID  Loan Status  Current Loan Amount   Term  \
# 2        False        False        False                False  False
# 6        False        False        False                False  False
# 8        False        False        False                False  False
# 10       False        False        False                False  False
# 12       False        False        False                False  False
# ...        ...          ...          ...                  ...    ...
# 99990    False        False        False                False  False
# 99993    False        False        False                False  False
# 99994    False        False        False                False  False
# 99996    False        False        False                False  False
# 99997    False        False        False                False  False
#
#        Credit Score  Annual Income  Years in current job  Home Ownership  \
# 2             False          False                 False           False
# 6             False          False                 False           False
# 8             False          False                 False           False
# 10            False          False                 False           False
# 12            False          False                 False           False
# ...             ...            ...                   ...             ...
# 99990         False          False                 False           False
# 99993         False          False                 False           False
# 99994         False          False                 False           False
# 99996         False          False                 False           False
# 99997         False          False                 False           False
#
#        Purpose  Monthly Debt  Years of Credit History  \
# 2        False         False                    False
# 6        False         False                    False
# 8        False         False                    False
# 10       False         False                    False
# 12       False         False                    False
# ...        ...           ...                      ...
# 99990    False         False                    False
# 99993    False         False                    False
# 99994    False         False                    False
# 99996    False         False                    False
# 99997    False         False                    False
#
#        Months since last delinquent  Number of Open Accounts  \
# 2                             False                    False
# 6                             False                    False
# 8                             False                    False
# 10                            False                    False
# 12                            False                    False
# ...                             ...                      ...
# 99990                         False                    False
# 99993                         False                    False
# 99994                         False                    False
# 99996                         False                    False
# 99997                         False                    False
#
#        Number of Credit Problems  Current Credit Balance  Maximum Open Credit  \
# 2                          False                   False                False
# 6                          False                   False                False
# 8                          False                   False                False
# 10                         False                   False                False
# 12                         False                   False                False
# ...                          ...                     ...                  ...
# 99990                      False                   False                False
# 99993                      False                   False                False
# 99994                      False                   False                False
# 99996                      False                   False                False
# 99997                      False                   False                False
#
#        Bankruptcies  Tax Liens
# 2             False      False
# 6             False      False
# 8             False      False
# 10            False      False
# 12            False      False
# ...             ...        ...
# 99990         False      False
# 99993         False      False
# 99994         False      False
# 99996         False      False
# 99997         False      False
#
# [36423 rows x 19 columns]

# %%
new_df_filter.isnull().sum()
# Out:
# Loan ID                         0
# Customer ID                     0
# Loan Status                     0
# Current Loan Amount             0
# Term                            0
# Credit Score                    0
# Annual Income                   0
# Years in current job            0
# Home Ownership                  0
# Purpose                         0
# Monthly Debt                    0
# Years of Credit History         0
# Months since last delinquent    0
# Number of Open Accounts         0
# Number of Credit Problems       0
# Current Credit Balance          0
# Maximum Open Credit             0
# Bankruptcies                    0
# Tax Liens                       0
# dtype: int64

# %%
new_df_filter.describe()
# Out:
#        Current Loan Amount  Credit Score  Annual Income   Monthly Debt  \
# count         3.642300e+04  36423.000000   3.642300e+04   36423.000000
# mean          1.377581e+07   1055.688905   1.464561e+06   19269.251544
# std           3.406789e+07   1438.252560   9.357681e+05   12100.926465
# min           2.145000e+04    585.000000   1.112450e+05       0.000000
# 25%           1.907840e+05    702.000000   9.309050e+05   11125.735000
# 50%           3.247200e+05    721.000000   1.260498e+06   17117.480000
# 75%           5.421900e+05    738.000000   1.742766e+06   24766.120000
# max           1.000000e+08   7510.000000   3.083900e+07  229057.920000
#
#        Years of Credit History  Months since last delinquent  \
# count             36423.000000                  36423.000000
# mean                 19.065000                     34.851358
# std                   6.654911                     21.916600
# min                   3.800000                      0.000000
# 25%                  14.500000                     16.000000
# 50%                  17.700000                     31.000000
# 75%                  22.400000                     51.000000
# max                  70.500000                    176.000000
#
#        Number of Open Accounts  Number of Credit Problems  \
# count             36423.000000               36423.000000
# mean                 11.490816                   0.186036
# std                   4.991626                   0.528248
# min                   1.000000                   0.000000
# 25%                   8.000000                   0.000000
# 50%                  11.000000                   0.000000
# 75%                  14.000000                   0.000000
# max                  48.000000                  15.000000
#
#        Current Credit Balance  Maximum Open Credit  Bankruptcies     Tax Liens
# count            3.642300e+04         3.642300e+04  36423.000000  36423.000000
# mean             2.636261e+05         6.651413e+05      0.114790      0.038575
# std              3.176197e+05         5.703167e+06      0.359648      0.298938
# min              0.000000e+00         0.000000e+00      0.000000      0.000000
# 25%              1.010515e+05         2.472910e+05      0.000000      0.000000
# 50%              1.869600e+05         4.214760e+05      0.000000      0.000000
# 75%              3.284340e+05         7.029660e+05      0.000000      0.000000
# max              7.350321e+06         7.982554e+08      7.000000     15.000000

# %%
# Replace specific values (e.g., 999) with NaN
new_df_filter.replace(99999999.0,np.nan, inplace=True)

# Perform mean imputation
new_df_filter = new_df_filter.fillna(new_df_filter.mean())
new_df_filter
# Out:
#                                     Loan ID  \
# 2      4eed4e6a-aa2f-4c91-8651-ce984ee8fb26
# 6      273581de-85d8-4332-81a5-19b04ce68666
# 8      8af915d9-9e91-44a0-b5a2-564a45c12089
# 10     32c2e48f-1ba8-45e0-a530-9a6622c18d9c
# 12     403d7235-0284-4bb6-919a-09402fecbf7b
# ...                                     ...
# 99990  686017b3-dc24-4f8a-af92-0bd077452d3d
# 99993  79b81158-5d55-4766-8ad6-ebcd683f7d59
# 99994  8506a4e9-af7d-47d2-a1bf-7ea2c41858f0
# 99996  06eba04f-58fc-424a-b666-ed72aa008900
# 99997  e1cb4050-eff5-4bdb-a1b0-aabd3f7eaac7
#
#                                 Customer ID Loan Status  Current Loan Amount  \
# 2      5efb2b2b-bf11-4dfd-a572-3761a2694725  Fully Paid        316018.694493
# 6      90a75dde-34d5-419c-90dc-1e58b04b3e35  Fully Paid        217646.000000
# 8      af534dea-d27e-4fd6-9de8-efaa52a78ec0  Fully Paid        548746.000000
# 10     0de7bcdb-ebf4-4608-ba39-05f083f855b6  Fully Paid        316018.694493
# 12     11581f68-de3c-49d8-80d9-22268ebb323b  Fully Paid        316018.694493
# ...                                     ...         ...                  ...
# 99990  1a583add-21ba-410f-9c42-757c4ed19322  Fully Paid        316018.694493
# 99993  e45e8dc4-05ad-4efe-92cc-784a6d5ef61a  Fully Paid         44484.000000
# 99994  be67200e-1ef1-4b63-86a6-2bf27d3c704d  Fully Paid        210584.000000
# 99996  77f2252a-b7d1-4b07-a746-1202a8304290  Fully Paid        316018.694493
# 99997  2ced5f10-bd60-4a11-9134-cadce4e7b0a3  Fully Paid        103136.000000
#
#              Term  Credit Score  Annual Income Years in current job  \
# 2      Short Term         741.0      2231892.0              8 years
# 6      Short Term         730.0      1184194.0             < 1 year
# 8      Short Term         678.0      2559110.0              2 years
# 10     Short Term         728.0       714628.0              3 years
# 12     Short Term         740.0       776188.0             < 1 year
# ...           ...           ...            ...                  ...
# 99990  Short Term         742.0      1190046.0             < 1 year
# 99993  Short Term         717.0      1152426.0            10+ years
# 99994  Short Term         719.0       783389.0               1 year
# 99996  Short Term         732.0      1289416.0               1 year
# 99997  Short Term         742.0      1150545.0              6 years
#
#       Home Ownership             Purpose  Monthly Debt  \
# 2           Own Home  Debt Consolidation      29200.53
# 6      Home Mortgage  Debt Consolidation      10855.08
# 8               Rent  Debt Consolidation      18660.28
# 10              Rent  Debt Consolidation      11851.06
# 12          Own Home  Debt Consolidation      11578.22
# ...              ...                 ...           ...
# 99990           Rent               other      11969.81
# 99993  Home Mortgage      small_business       6280.64
# 99994  Home Mortgage               Other       3727.61
# 99996           Rent  Debt Consolidation      13109.05
# 99997           Rent  Debt Consolidation       7315.57
#
#        Years of Credit History  Months since last delinquent  \
# 2                         14.9                          29.0
# 6                         19.6                          10.0
# 8                         22.6                          33.0
# 10                        16.0                          76.0
# 12                         8.5                          25.0
# ...                        ...                           ...
# 99990                     20.1                          16.0
# 99993                     21.0                          12.0
# 99994                     17.4                          18.0
# 99996                      9.4                          21.0
# 99997                     18.8                          18.0
#
#        Number of Open Accounts  Number of Credit Problems  \
# 2                         18.0                        1.0
# 6                         13.0                        1.0
# 8                          4.0                        0.0
# 10                        16.0                        0.0
# 12                         6.0                        0.0
# ...                        ...                        ...
# 99990                      9.0                        0.0
# 99993                      6.0                        0.0
# 99994                      6.0                        0.0
# 99996                     22.0                        0.0
# 99997                     12.0                        1.0
#
#        Current Credit Balance  Maximum Open Credit  Bankruptcies  Tax Liens
# 2                    297996.0             750090.0           0.0        0.0
# 6                    122170.0             272052.0           1.0        0.0
# 8                    437171.0             555038.0           0.0        0.0
# 10                   203965.0             289784.0           0.0        0.0
# 12                   134083.0             220220.0           0.0        0.0
# ...                       ...                  ...           ...        ...
# 99990                 37392.0             134442.0           0.0        0.0
# 99993                961932.0                  0.0           0.0        0.0
# 99994                   456.0             259160.0           0.0        0.0
# 99996                153045.0             509234.0           0.0        0.0
# 99997                109554.0             537548.0           1.0        0.0
#
# [36423 rows x 19 columns]

# %%
# Define a function to perform range normalization
def range_normalization(x):
    return (x - x.min()) / (x.max() - x.min())

# Apply the range normalization function to all columns except the non-numeric ones
new_df_filter[new_df_filter.select_dtypes(include=['float64', 'int64']).columns] = new_df_filter[new_df_filter.select_dtypes(include=['float64', 'int64']).columns].apply(range_normalization)

new_df_filter
# Out:
#                                     Loan ID  \
# 2      4eed4e6a-aa2f-4c91-8651-ce984ee8fb26
# 6      273581de-85d8-4332-81a5-19b04ce68666
# 8      8af915d9-9e91-44a0-b5a2-564a45c12089
# 10     32c2e48f-1ba8-45e0-a530-9a6622c18d9c
# 12     403d7235-0284-4bb6-919a-09402fecbf7b
# ...                                     ...
# 99990  686017b3-dc24-4f8a-af92-0bd077452d3d
# 99993  79b81158-5d55-4766-8ad6-ebcd683f7d59
# 99994  8506a4e9-af7d-47d2-a1bf-7ea2c41858f0
# 99996  06eba04f-58fc-424a-b666-ed72aa008900
# 99997  e1cb4050-eff5-4bdb-a1b0-aabd3f7eaac7
#
#                                 Customer ID Loan Status  Current Loan Amount  \
# 2      5efb2b2b-bf11-4dfd-a572-3761a2694725  Fully Paid             0.383653
# 6      90a75dde-34d5-419c-90dc-1e58b04b3e35  Fully Paid             0.255530
# 8      af534dea-d27e-4fd6-9de8-efaa52a78ec0  Fully Paid             0.686762
# 10     0de7bcdb-ebf4-4608-ba39-05f083f855b6  Fully Paid             0.383653
# 12     11581f68-de3c-49d8-80d9-22268ebb323b  Fully Paid             0.383653
# ...                                     ...         ...                  ...
# 99990  1a583add-21ba-410f-9c42-757c4ed19322  Fully Paid             0.383653
# 99993  e45e8dc4-05ad-4efe-92cc-784a6d5ef61a  Fully Paid             0.030000
# 99994  be67200e-1ef1-4b63-86a6-2bf27d3c704d  Fully Paid             0.246332
# 99996  77f2252a-b7d1-4b07-a746-1202a8304290  Fully Paid             0.383653
# 99997  2ced5f10-bd60-4a11-9134-cadce4e7b0a3  Fully Paid             0.106390
#
#              Term  Credit Score  Annual Income Years in current job  \
# 2      Short Term      0.022527       0.069014              8 years
# 6      Short Term      0.020939       0.034918             < 1 year
# 8      Short Term      0.013430       0.079663              2 years
# 10     Short Term      0.020650       0.019636              3 years
# 12     Short Term      0.022383       0.021640             < 1 year
# ...           ...           ...            ...                  ...
# 99990  Short Term      0.022671       0.035108             < 1 year
# 99993  Short Term      0.019061       0.033884            10+ years
# 99994  Short Term      0.019350       0.021874               1 year
# 99996  Short Term      0.021227       0.038342               1 year
# 99997  Short Term      0.022671       0.033823              6 years
#
#       Home Ownership             Purpose  Monthly Debt  \
# 2           Own Home  Debt Consolidation      0.127481
# 6      Home Mortgage  Debt Consolidation      0.047390
# 8               Rent  Debt Consolidation      0.081465
# 10              Rent  Debt Consolidation      0.051738
# 12          Own Home  Debt Consolidation      0.050547
# ...              ...                 ...           ...
# 99990           Rent               other      0.052257
# 99993  Home Mortgage      small_business      0.027419
# 99994  Home Mortgage               Other      0.016274
# 99996           Rent  Debt Consolidation      0.057230
# 99997           Rent  Debt Consolidation      0.031938
#
#        Years of Credit History  Months since last delinquent  \
# 2                     0.166417                      0.164773
# 6                     0.236882                      0.056818
# 8                     0.281859                      0.187500
# 10                    0.182909                      0.431818
# 12                    0.070465                      0.142045
# ...                        ...                           ...
# 99990                 0.244378                      0.090909
# 99993                 0.257871                      0.068182
# 99994                 0.203898                      0.102273
# 99996                 0.083958                      0.119318
# 99997                 0.224888                      0.102273
#
#        Number of Open Accounts  Number of Credit Problems  \
# 2                     0.361702                   0.066667
# 6                     0.255319                   0.066667
# 8                     0.063830                   0.000000
# 10                    0.319149                   0.000000
# 12                    0.106383                   0.000000
# ...                        ...                        ...
# 99990                 0.170213                   0.000000
# 99993                 0.106383                   0.000000
# 99994                 0.106383                   0.000000
# 99996                 0.446809                   0.000000
# 99997                 0.234043                   0.066667
#
#        Current Credit Balance  Maximum Open Credit  Bankruptcies  Tax Liens
# 2                    0.040542             0.000940      0.000000        0.0
# 6                    0.016621             0.000341      0.142857        0.0
# 8                    0.059476             0.000695      0.000000        0.0
# 10                   0.027749             0.000363      0.000000        0.0
# 12                   0.018242             0.000276      0.000000        0.0
# ...                       ...                  ...           ...        ...
# 99990                0.005087             0.000168      0.000000        0.0
# 99993                0.130869             0.000000      0.000000        0.0
# 99994                0.000062             0.000325      0.000000        0.0
# 99996                0.020822             0.000638      0.000000        0.0
# 99997                0.014905             0.000673      0.142857        0.0
#
# [36423 rows x 19 columns]

# %%
new_df_filter.shape
# Out:
# (36423, 19)

# %%
# begin encoding
# get info about all the datatypes
new_df_filter.dtypes
# Out:
# Loan ID                          object
# Customer ID                      object
# Loan Status                      object
# Current Loan Amount             float64
# Term                             object
# Credit Score                    float64
# Annual Income                   float64
# Years in current job             object
# Home Ownership                   object
# Purpose                          object
# Monthly Debt                    float64
# Years of Credit History         float64
# Months since last delinquent    float64
# Number of Open Accounts         float64
# Number of Credit Problems       float64
# Current Credit Balance          float64
# Maximum Open Credit             float64
# Bankruptcies                    float64
# Tax Liens                       float64
# dtype: object

# %%
# drop the id columns
new_df_filter.drop(columns=['Loan ID'], inplace=True)
new_df_filter.drop(columns=['Customer ID'], inplace=True)

# Select the categorical columns
cat_cols = ['Term', 'Years in current job', 'Home Ownership', 'Purpose']

# encode the categorical columns
new_df_filter = pd.get_dummies(new_df_filter, columns=cat_cols)
# Print the modified dataset
print(new_df_filter)
# Out:
#       Loan Status  Current Loan Amount  Credit Score  Annual Income  \
# 2      Fully Paid             0.383653      0.022527       0.069014
# 6      Fully Paid             0.255530      0.020939       0.034918
# 8      Fully Paid             0.686762      0.013430       0.079663
# 10     Fully Paid             0.383653      0.020650       0.019636
# 12     Fully Paid             0.383653      0.022383       0.021640
# ...           ...                  ...           ...            ...
# 99990  Fully Paid             0.383653      0.022671       0.035108
# 99993  Fully Paid             0.030000      0.019061       0.033884
# 99994  Fully Paid             0.246332      0.019350       0.021874
# 99996  Fully Paid             0.383653      0.021227       0.038342
# 99997  Fully Paid             0.106390      0.022671       0.033823
#
#        Monthly Debt  Years of Credit History  Months since last delinquent  \
# 2          0.127481                 0.166417                      0.164773
# 6          0.047390                 0.236882                      0.056818
# 8          0.081465                 0.281859                      0.187500
# 10         0.051738                 0.182909                      0.431818
# 12         0.050547                 0.070465                      0.142045
# ...             ...                      ...                           ...
# 99990      0.052257                 0.244378                      0.090909
# 99993      0.027419                 0.257871                      0.068182
# 99994      0.016274                 0.203898                      0.102273
# 99996      0.057230                 0.083958                      0.119318
# 99997      0.031938                 0.224888                      0.102273
#
#        Number of Open Accounts  Number of Credit Problems  \
# 2                     0.361702                   0.066667
# 6                     0.255319                   0.066667
# 8                     0.063830                   0.000000
# 10                    0.319149                   0.000000
# 12                    0.106383                   0.000000
# ...                        ...                        ...
# 99990                 0.170213                   0.000000
# 99993                 0.106383                   0.000000
# 99994                 0.106383                   0.000000
# 99996                 0.446809                   0.000000
# 99997                 0.234043                   0.066667
#
#        Current Credit Balance  ...  Purpose_Medical Bills  Purpose_Other  \
# 2                    0.040542  ...                      0              0
# 6                    0.016621  ...                      0              0
# 8                    0.059476  ...                      0              0
# 10                   0.027749  ...                      0              0
# 12                   0.018242  ...                      0              0
# ...                       ...  ...                    ...            ...
# 99990                0.005087  ...                      0              0
# 99993                0.130869  ...                      0              0
# 99994                0.000062  ...                      0              1
# 99996                0.020822  ...                      0              0
# 99997                0.014905  ...                      0              0
#
#        Purpose_Take a Trip  Purpose_major_purchase  Purpose_moving  \
# 2                        0                       0               0
# 6                        0                       0               0
# 8                        0                       0               0
# 10                       0                       0               0
# 12                       0                       0               0
# ...                    ...                     ...             ...
# 99990                    0                       0               0
# 99993                    0                       0               0
# 99994                    0                       0               0
# 99996                    0                       0               0
# 99997                    0                       0               0
#
#        Purpose_other  Purpose_renewable_energy  Purpose_small_business  \
# 2                  0                         0                       0
# 6                  0                         0                       0
# 8                  0                         0                       0
# 10                 0                         0                       0
# 12                 0                         0                       0
# ...              ...                       ...                     ...
# 99990              1                         0                       0
# 99993              0                         0                       1
# 99994              0                         0                       0
# 99996              0                         0                       0
# 99997              0                         0                       0
#
#        Purpose_vacation  Purpose_wedding
# 2                     0                0
# 6                     0                0
# 8                     0                0
# 10                    0                0
# 12                    0                0
# ...                 ...              ...
# 99990                 0                0
# 99993                 0                0
# 99994                 0                0
# 99996                 0                0
# 99997                 0                0
#
# [36423 rows x 46 columns]

# %%
# separate x and y
# separate x and y
import re
regex = re.compile(r"\[|\]|<", re.IGNORECASE)
new_df_filter.columns = [regex.sub("_", col) if any(x in str(col) for x in set(('[', ']', '<'))) else col for col in new_df_filter.columns.values]
target_column = "Loan Status"
y = new_df_filter[target_column]
X = new_df_filter.drop(target_column, axis=1)

# %%
X
# Out:
#        Current Loan Amount  Credit Score  Annual Income  Monthly Debt  \
# 2                 0.383653      0.022527       0.069014      0.127481
# 6                 0.255530      0.020939       0.034918      0.047390
# 8                 0.686762      0.013430       0.079663      0.081465
# 10                0.383653      0.020650       0.019636      0.051738
# 12                0.383653      0.022383       0.021640      0.050547
# ...                    ...           ...            ...           ...
# 99990             0.383653      0.022671       0.035108      0.052257
# 99993             0.030000      0.019061       0.033884      0.027419
# 99994             0.246332      0.019350       0.021874      0.016274
# 99996             0.383653      0.021227       0.038342      0.057230
# 99997             0.106390      0.022671       0.033823      0.031938
#
#        Years of Credit History  Months since last delinquent  \
# 2                     0.166417                      0.164773
# 6                     0.236882                      0.056818
# 8                     0.281859                      0.187500
# 10                    0.182909                      0.431818
# 12                    0.070465                      0.142045
# ...                        ...                           ...
# 99990                 0.244378                      0.090909
# 99993                 0.257871                      0.068182
# 99994                 0.203898                      0.102273
# 99996                 0.083958                      0.119318
# 99997                 0.224888                      0.102273
#
#        Number of Open Accounts  Number of Credit Problems  \
# 2                     0.361702                   0.066667
# 6                     0.255319                   0.066667
# 8                     0.063830                   0.000000
# 10                    0.319149                   0.000000
# 12                    0.106383                   0.000000
# ...                        ...                        ...
# 99990                 0.170213                   0.000000
# 99993                 0.106383                   0.000000
# 99994                 0.106383                   0.000000
# 99996                 0.446809                   0.000000
# 99997                 0.234043                   0.066667
#
#        Current Credit Balance  Maximum Open Credit  ...  \
# 2                    0.040542             0.000940  ...
# 6                    0.016621             0.000341  ...
# 8                    0.059476             0.000695  ...
# 10                   0.027749             0.000363  ...
# 12                   0.018242             0.000276  ...
# ...                       ...                  ...  ...
# 99990                0.005087             0.000168  ...
# 99993                0.130869             0.000000  ...
# 99994                0.000062             0.000325  ...
# 99996                0.020822             0.000638  ...
# 99997                0.014905             0.000673  ...
#
#        Purpose_Medical Bills  Purpose_Other  Purpose_Take a Trip  \
# 2                          0              0                    0
# 6                          0              0                    0
# 8                          0              0                    0
# 10                         0              0                    0
# 12                         0              0                    0
# ...                      ...            ...                  ...
# 99990                      0              0                    0
# 99993                      0              0                    0
# 99994                      0              1                    0
# 99996                      0              0                    0
# 99997                      0              0                    0
#
#        Purpose_major_purchase  Purpose_moving  Purpose_other  \
# 2                           0               0              0
# 6                           0               0              0
# 8                           0               0              0
# 10                          0               0              0
# 12                          0               0              0
# ...                       ...             ...            ...
# 99990                       0               0              1
# 99993                       0               0              0
# 99994                       0               0              0
# 99996                       0               0              0
# 99997                       0               0              0
#
#        Purpose_renewable_energy  Purpose_small_business  Purpose_vacation  \
# 2                             0                       0                 0
# 6                             0                       0                 0
# 8                             0                       0                 0
# 10                            0                       0                 0
# 12                            0                       0                 0
# ...                         ...                     ...               ...
# 99990                         0                       0                 0
# 99993                         0                       1                 0
# 99994                         0                       0                 0
# 99996                         0                       0                 0
# 99997                         0                       0                 0
#
#        Purpose_wedding
# 2                    0
# 6                    0
# 8                    0
# 10                   0
# 12                   0
# ...                ...
# 99990                0
# 99993                0
# 99994                0
# 99996                0
# 99997                0
#
# [36423 rows x 45 columns]

# %%
y
# Out:
# 2        Fully Paid
# 6        Fully Paid
# 8        Fully Paid
# 10       Fully Paid
# 12       Fully Paid
#             ...
# 99990    Fully Paid
# 99993    Fully Paid
# 99994    Fully Paid
# 99996    Fully Paid
# 99997    Fully Paid
# Name: Loan Status, Length: 36423, dtype: object

# %%
# encode y
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)

# begin oversampling according to target feature
from imblearn import under_sampling, over_sampling
from imblearn.over_sampling import SMOTE
# Count the number of samples in each class
class_counts = np.bincount(y)

# Find the minority class with the lowest count
minority_class = np.argmin(class_counts)

# Apply SMOTE to oversample the minority class
smote = SMOTE()
X, y = smote.fit_resample(X, y)

# %%
X
# Out:
#        Current Loan Amount  Credit Score  Annual Income  Monthly Debt  \
# 0                 0.383653      0.022527       0.069014      0.127481
# 1                 0.255530      0.020939       0.034918      0.047390
# 2                 0.686762      0.013430       0.079663      0.081465
# 3                 0.383653      0.020650       0.019636      0.051738
# 4                 0.383653      0.022383       0.021640      0.050547
# ...                    ...           ...            ...           ...
# 57939             0.186459      0.017665       0.031806      0.080840
# 57940             0.273757      0.014286       0.031229      0.090481
# 57941             0.332522      0.872178       0.026438      0.067990
# 57942             0.933832      0.014752       0.107468      0.077946
# 57943             0.187118      0.021960       0.019494      0.039647
#
#        Years of Credit History  Months since last delinquent  \
# 0                     0.166417                      0.164773
# 1                     0.236882                      0.056818
# 2                     0.281859                      0.187500
# 3                     0.182909                      0.431818
# 4                     0.070465                      0.142045
# ...                        ...                           ...
# 57939                 0.242615                      0.296178
# 57940                 0.245493                      0.043294
# 57941                 0.238225                      0.221189
# 57942                 0.366924                      0.430921
# 57943                 0.355069                      0.364607
#
#        Number of Open Accounts  Number of Credit Problems  \
# 0                     0.361702                   0.066667
# 1                     0.255319                   0.066667
# 2                     0.063830                   0.000000
# 3                     0.319149                   0.000000
# 4                     0.106383                   0.000000
# ...                        ...                        ...
# 57939                 0.396454                   0.000000
# 57940                 0.271504                   0.000000
# 57941                 0.192996                   0.000000
# 57942                 0.328117                   0.154380
# 57943                 0.072651                   0.000000
#
#        Current Credit Balance  Maximum Open Credit  ...  \
# 0                    0.040542             0.000940  ...
# 1                    0.016621             0.000341  ...
# 2                    0.059476             0.000695  ...
# 3                    0.027749             0.000363  ...
# 4                    0.018242             0.000276  ...
# ...                       ...                  ...  ...
# 57939                0.037595             0.000975  ...
# 57940                0.014508             0.000256  ...
# 57941                0.023622             0.000475  ...
# 57942                0.062990             0.001955  ...
# 57943                0.011015             0.000193  ...
#
#        Purpose_Medical Bills  Purpose_Other  Purpose_Take a Trip  \
# 0                          0              0                    0
# 1                          0              0                    0
# 2                          0              0                    0
# 3                          0              0                    0
# 4                          0              0                    0
# ...                      ...            ...                  ...
# 57939                      0              0                    0
# 57940                      0              0                    0
# 57941                      0              0                    0
# 57942                      0              0                    0
# 57943                      0              0                    0
#
#        Purpose_major_purchase  Purpose_moving  Purpose_other  \
# 0                           0               0              0
# 1                           0               0              0
# 2                           0               0              0
# 3                           0               0              0
# 4                           0               0              0
# ...                       ...             ...            ...
# 57939                       0               0              0
# 57940                       0               0              0
# 57941                       0               0              0
# 57942                       0               0              0
# 57943                       0               0              0
#
#        Purpose_renewable_energy  Purpose_small_business  Purpose_vacation  \
# 0                             0                       0                 0
# 1                             0                       0                 0
# 2                             0                       0                 0
# 3                             0                       0                 0
# 4                             0                       0                 0
# ...                         ...                     ...               ...
# 57939                         0                       0                 0
# 57940                         0                       0                 0
# 57941                         0                       0                 0
# 57942                         0                       0                 0
# 57943                         0                       0                 0
#
#        Purpose_wedding
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 57939                0
# 57940                0
# 57941                0
# 57942                0
# 57943                0
#
# [57944 rows x 45 columns]

# %%
# splitting
from sklearn.model_selection import train_test_split
# Splitting the dataset into training and temporary sets (60% for training and 40% for temporary)
X_train, X_tmp, y_train, y_tmp = train_test_split(X, y, test_size=0.4, random_state=42)

# Splitting the temporary set into validation and testing sets (50% for each)
X_val, X_test, y_val, y_test = train_test_split(X_tmp, y_tmp, test_size=0.5, random_state=42)

X_train
# Out:
#        Current Loan Amount  Credit Score  Annual Income  Monthly Debt  \
# 33681             0.391862      0.020650       0.050733      0.037733
# 13260             0.135673      0.022094       0.012141      0.052859
# 24211             0.728395      0.011408       0.033509      0.036195
# 12973             0.694785      0.011552       0.053773      0.182214
# 24050             0.261289      0.018917       0.023193      0.059050
# ...                    ...           ...            ...           ...
# 54343             0.822425      0.968160       0.047349      0.082100
# 38158             0.184620      0.022199       0.013303      0.022090
# 860               0.383653      0.015307       0.030258      0.084077
# 15795             0.846877      0.018773       0.071893      0.133379
# 56422             0.286189      0.022005       0.019802      0.053614
#
#        Years of Credit History  Months since last delinquent  \
# 33681                 0.367316                      0.215909
# 13260                 0.154423                      0.085227
# 24211                 0.218891                      0.130682
# 12973                 0.413793                      0.085227
# 24050                 0.209895                      0.136364
# ...                        ...                           ...
# 54343                 0.554669                      0.074289
# 38158                 0.132423                      0.227932
# 860                   0.296852                      0.340909
# 15795                 0.227886                      0.096591
# 56422                 0.161850                      0.169439
#
#        Number of Open Accounts  Number of Credit Problems  \
# 33681                 0.148936                   0.066667
# 13260                 0.127660                   0.000000
# 24211                 0.170213                   0.000000
# 12973                 0.297872                   0.000000
# 24050                 0.297872                   0.000000
# ...                        ...                        ...
# 54343                 0.203548                   0.042779
# 38158                 0.133537                   0.000000
# 860                   0.106383                   0.000000
# 15795                 0.319149                   0.000000
# 56422                 0.236297                   0.000000
#
#        Current Credit Balance  Maximum Open Credit  ...  \
# 33681                0.043199             0.000673  ...
# 13260                0.018244             0.000323  ...
# 24211                0.056618             0.001258  ...
# 12973                0.052179             0.000703  ...
# 24050                0.020757             0.000303  ...
# ...                       ...                  ...  ...
# 54343                0.059907             0.001307  ...
# 38158                0.012334             0.000184  ...
# 860                  0.033563             0.000377  ...
# 15795                0.066538             0.002288  ...
# 56422                0.037344             0.000732  ...
#
#        Purpose_Medical Bills  Purpose_Other  Purpose_Take a Trip  \
# 33681                      0              0                    0
# 13260                      0              0                    0
# 24211                      0              0                    0
# 12973                      0              0                    0
# 24050                      0              0                    0
# ...                      ...            ...                  ...
# 54343                      0              0                    0
# 38158                      0              0                    0
# 860                        0              0                    0
# 15795                      0              0                    0
# 56422                      0              0                    0
#
#        Purpose_major_purchase  Purpose_moving  Purpose_other  \
# 33681                       0               0              0
# 13260                       0               0              0
# 24211                       0               0              0
# 12973                       0               0              0
# 24050                       0               0              0
# ...                       ...             ...            ...
# 54343                       0               0              0
# 38158                       0               0              0
# 860                         0               0              0
# 15795                       0               0              0
# 56422                       0               0              0
#
#        Purpose_renewable_energy  Purpose_small_business  Purpose_vacation  \
# 33681                         0                       0                 0
# 13260                         0                       0                 0
# 24211                         0                       0                 0
# 12973                         0                       0                 0
# 24050                         0                       0                 0
# ...                         ...                     ...               ...
# 54343                         0                       0                 0
# 38158                         0                       0                 0
# 860                           0                       0                 0
# 15795                         0                       0                 0
# 56422                         0                       0                 0
#
#        Purpose_wedding
# 33681                0
# 13260                0
# 24211                0
# 12973                0
# 24050                0
# ...                ...
# 54343                0
# 38158                0
# 860                  0
# 15795                0
# 56422                0
#
# [34766 rows x 45 columns]

# %%
X_val
# Out:
#        Current Loan Amount  Credit Score  Annual Income  Monthly Debt  \
# 30547             0.383653      0.015451       0.064845      0.135472
# 43672             0.318123      0.018049       0.015685      0.023983
# 23743             0.383653      0.009675       0.023109      0.006245
# 57394             0.741749      0.018327       0.055685      0.071827
# 33335             0.182235      0.018484       0.059876      0.075952
# ...                    ...           ...            ...           ...
# 5568              0.187106      0.009531       0.017168      0.019498
# 3100              0.175129      0.022527       0.090280      0.120717
# 3241              0.375358      0.009964       0.047014      0.106982
# 40590             0.367836      0.947135       0.022532      0.077707
# 5426              0.643524      0.023249       0.117128      0.111632
#
#        Years of Credit History  Months since last delinquent  \
# 30547                 0.107946                      0.176136
# 43672                 0.216779                      0.023671
# 23743                 0.403298                      0.068182
# 57394                 0.206220                      0.046702
# 33335                 0.247376                      0.215909
# ...                        ...                           ...
# 5568                  0.278861                      0.068182
# 3100                  0.145427                      0.340909
# 3241                  0.199400                      0.017045
# 40590                 0.174402                      0.278698
# 5426                  0.206897                      0.051136
#
#        Number of Open Accounts  Number of Credit Problems  \
# 30547                 0.127660                   0.000000
# 43672                 0.297872                   0.000000
# 23743                 0.170213                   0.066667
# 57394                 0.153608                   0.003659
# 33335                 0.170213                   0.000000
# ...                        ...                        ...
# 5568                  0.021277                   0.066667
# 3100                  0.127660                   0.000000
# 3241                  0.234043                   0.000000
# 40590                 0.306352                   0.000000
# 5426                  0.234043                   0.000000
#
#        Current Credit Balance  Maximum Open Credit  ...  \
# 30547                0.003107             0.000106  ...
# 43672                0.017477             0.000804  ...
# 23743                0.000667             0.000113  ...
# 57394                0.025730             0.000359  ...
# 33335                0.039128             0.000434  ...
# ...                       ...                  ...  ...
# 5568                 0.001864             0.000036  ...
# 3100                 0.084400             0.000997  ...
# 3241                 0.029398             0.000432  ...
# 40590                0.045001             0.000778  ...
# 5426                 0.019519             0.000334  ...
#
#        Purpose_Medical Bills  Purpose_Other  Purpose_Take a Trip  \
# 30547                      0              0                    0
# 43672                      0              0                    0
# 23743                      0              0                    0
# 57394                      0              0                    0
# 33335                      0              0                    0
# ...                      ...            ...                  ...
# 5568                       0              0                    0
# 3100                       0              0                    0
# 3241                       0              0                    0
# 40590                      0              0                    0
# 5426                       0              0                    0
#
#        Purpose_major_purchase  Purpose_moving  Purpose_other  \
# 30547                       0               0              0
# 43672                       0               0              0
# 23743                       0               0              0
# 57394                       0               0              0
# 33335                       0               0              0
# ...                       ...             ...            ...
# 5568                        0               0              1
# 3100                        0               0              0
# 3241                        0               0              0
# 40590                       0               0              1
# 5426                        0               0              0
#
#        Purpose_renewable_energy  Purpose_small_business  Purpose_vacation  \
# 30547                         0                       0                 0
# 43672                         0                       0                 0
# 23743                         0                       0                 0
# 57394                         0                       0                 0
# 33335                         0                       0                 0
# ...                         ...                     ...               ...
# 5568                          0                       0                 0
# 3100                          0                       0                 0
# 3241                          0                       0                 0
# 40590                         0                       0                 0
# 5426                          0                       0                 0
#
#        Purpose_wedding
# 30547                0
# 43672                0
# 23743                0
# 57394                0
# 33335                0
# ...                ...
# 5568                 0
# 3100                 0
# 3241                 0
# 40590                0
# 5426                 0
#
# [11589 rows x 45 columns]

# %%
X_test
# Out:
#        Current Loan Amount  Credit Score  Annual Income  Monthly Debt  \
# 28458             0.117593      0.019206       0.021501      0.062626
# 19443             0.383653      0.023538       0.071971      0.113235
# 25424             0.546447      0.020939       0.029846      0.080438
# 50260             0.199648      0.018292       0.024486      0.060141
# 19578             0.975530      0.014440       0.447643      0.600318
# ...                    ...           ...            ...           ...
# 32135             0.394040      0.017906       0.057088      0.080081
# 16604             0.383653      0.019061       0.037598      0.074647
# 20974             0.370860      0.018339       0.024544      0.092566
# 15653             0.410774      0.023394       0.025412      0.058743
# 13558             0.383653      0.022671       0.075526      0.247740
#
#        Years of Credit History  Months since last delinquent  \
# 28458                 0.226387                      0.090909
# 19443                 0.445277                      0.380682
# 25424                 0.155922                      0.085227
# 50260                 0.329212                      0.042811
# 19578                 0.367316                      0.051136
# ...                        ...                           ...
# 32135                 0.190405                      0.034091
# 16604                 0.194903                      0.125000
# 20974                 0.160420                      0.062500
# 15653                 0.200900                      0.238636
# 13558                 0.212894                      0.073864
#
#        Number of Open Accounts  Number of Credit Problems  \
# 28458                 0.148936                   0.000000
# 19443                 0.446809                   0.000000
# 25424                 0.234043                   0.000000
# 50260                 0.195945                   0.000000
# 19578                 0.212766                   0.000000
# ...                        ...                        ...
# 32135                 0.276596                   0.133333
# 16604                 0.276596                   0.000000
# 20974                 0.212766                   0.000000
# 15653                 0.319149                   0.000000
# 13558                 0.170213                   0.000000
#
#        Current Credit Balance  Maximum Open Credit  ...  \
# 28458                0.041090             0.000666  ...
# 19443                0.095870             0.002929  ...
# 25424                0.054270             0.000897  ...
# 50260                0.009457             0.000349  ...
# 19578                0.240131             0.002926  ...
# ...                       ...                  ...  ...
# 32135                0.022507             0.000390  ...
# 16604                0.010624             0.000322  ...
# 20974                0.027292             0.000435  ...
# 15653                0.013933             0.000990  ...
# 13558                0.022424             0.000291  ...
#
#        Purpose_Medical Bills  Purpose_Other  Purpose_Take a Trip  \
# 28458                      0              0                    0
# 19443                      0              0                    0
# 25424                      0              0                    0
# 50260                      0              0                    0
# 19578                      0              0                    0
# ...                      ...            ...                  ...
# 32135                      0              0                    0
# 16604                      0              0                    0
# 20974                      0              0                    0
# 15653                      0              0                    0
# 13558                      0              0                    0
#
#        Purpose_major_purchase  Purpose_moving  Purpose_other  \
# 28458                       0               0              1
# 19443                       0               0              0
# 25424                       0               0              0
# 50260                       0               0              0
# 19578                       0               0              0
# ...                       ...             ...            ...
# 32135                       0               0              0
# 16604                       0               0              0
# 20974                       0               0              0
# 15653                       0               0              0
# 13558                       0               0              0
#
#        Purpose_renewable_energy  Purpose_small_business  Purpose_vacation  \
# 28458                         0                       0                 0
# 19443                         0                       0                 0
# 25424                         0                       0                 0
# 50260                         0                       0                 0
# 19578                         0                       0                 0
# ...                         ...                     ...               ...
# 32135                         0                       0                 0
# 16604                         0                       0                 0
# 20974                         0                       0                 0
# 15653                         0                       0                 0
# 13558                         0                       0                 0
#
#        Purpose_wedding
# 28458                0
# 19443                0
# 25424                0
# 50260                0
# 19578                0
# ...                ...
# 32135                0
# 16604                0
# 20974                0
# 15653                0
# 13558                0
#
# [11589 rows x 45 columns]

# %%
# random forest
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
# Make predictions on the testing data
y_pred = rf.predict(X_val)
# Evaluate the model's accuracy
accuracy = accuracy_score(y_val, y_pred)
print('RF accuracy:', accuracy)
# Out:
# RF accuracy: 0.8756579515057382

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
cm = confusion_matrix(y_val, y_pred)
print(cm)
# Out:
# [[4883  882]
#  [ 543 5281]]

# %%
display = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=None)
display.plot(cmap=plt.cm.Blues)

# %%
from sklearn.metrics import precision_score, f1_score, roc_curve, auc, log_loss,recall_score
# calculate the precision of the model
precision = precision_score(y_val, y_pred, average='macro')
# calculate the F1 score of the model
f1 = f1_score(y_val, y_pred, average='macro')
# calculate the ROC curve and AUC of the model
y_prob = rf.predict_proba(X_val)
fpr, tpr, thresholds = roc_curve(y_val, y_prob[:, 1],pos_label=1)
roc_auc = auc(fpr, tpr)
# calculate the log loss of the model
logloss = log_loss(y_val, y_prob)
# Calculate the recall score
recall = recall_score(y_val, y_pred)
# Calculate the precision score
precision = precision_score(y_val, y_pred)

# %%
# plot the ROC curve
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
#plt.xlim([0.0, 1.0])
#plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for RF')
plt.legend(loc="lower right")
plt.show()

# %%
print("RF F1 Score:",f1)
print("RF AUC: ",roc_auc)
print("RF Log Loss: ",logloss)
print("RF Recall:", recall)
print("RF Precision: ", precision)
# Out:
# RF F1 Score: 0.8768933747269785
# RF AUC:  0.9518254606949859
# RF Log Loss:  0.35083137694571875
# RF Recall: 0.9067651098901099
# RF Precision:  0.8568878792795717

# %%
from sklearn.metrics import classification_report
print("               RF classification report")
print(classification_report(y_val, y_pred))
# Out:
#                RF classification report
#               precision    recall  f1-score   support
#
#            0       0.90      0.85      0.87      5765
#            1       0.86      0.91      0.88      5824
#
#     accuracy                           0.88     11589
#    macro avg       0.88      0.88      0.88     11589
# weighted avg       0.88      0.88      0.88     11589

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'n_estimators': [50, 100, 200], 
              'max_depth': [2,4,6,3, 5, 7], 
              'min_samples_split': [2, 4, 6]}

grid_search = GridSearchCV(rf, param_grid=param_grid, cv=5, n_jobs=-1)
grid_search.fit(X_train, y_train)

print("Best Parameters: ", grid_search.best_params_)
print("Best Score:", grid_search.best_score_ )
# Out:
# Best Parameters:  {'max_depth': 7, 'min_samples_split': 2, 'n_estimators': 100}
# Best Score: 0.7209341111595208

# %%
# rf tunning
rf_tunned = RandomForestClassifier(max_depth=7,n_estimators=100,random_state = 42,min_samples_split=2)
rf_tunned.fit(X_train , y_train)
y_pred_tunned = rf_tunned.predict(X_test)
accuracy_tunned = accuracy_score(y_test, y_pred_tunned)
print("Tuned RF Accuracy:", accuracy_tunned)
# Out:
# Tuned RF Accuracy: 0.7013547329364052

# %%
cm_tunned = confusion_matrix(y_test, y_pred_tunned)
print(cm_tunned)
# Out:
# [[3172 2635]
#  [ 826 4956]]

# %%
display = ConfusionMatrixDisplay(confusion_matrix=cm_tunned, display_labels=None)
display.plot(cmap=plt.cm.Blues)

# %%
from sklearn.metrics import precision_score, f1_score, roc_curve, auc, log_loss
# calculate the precision of the model
precision_tunned = precision_score(y_test, y_pred_tunned, average='macro')
# calculate the F1 score of the model
f1_tunned = f1_score(y_test, y_pred_tunned, average='macro')
# calculate the ROC curve and AUC of the model
y_prob_tunned = rf_tunned.predict_proba(X_test)
fpr_tunned, tpr_tunned, thresholds_tunned = roc_curve(y_test, y_prob_tunned[:, 1],pos_label=1)
roc_auc_tunned = auc(fpr_tunned, tpr_tunned)
# calculate the log loss of the model
logloss_tunned = log_loss(y_test, y_prob_tunned)
# Calculate the recall score
recall_tunned = recall_score(y_test, y_pred_tunned)
# Calculate the precision score
precision_tunned = precision_score(y_test, y_pred_tunned)

# %%
# plot the ROC curve
plt.plot(fpr_tunned, tpr_tunned, color='darkorange', lw=2, label='ROC curve (AUC = {:.2f})'.format(roc_auc_tunned))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
#plt.xlim([0.0, 1.0])
#plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for Tuned RF')
plt.legend(loc="lower right")
plt.show()

# %%
print("Tuned RF F1 Score: ",f1_tunned)
print("Tuned RF AUC: ", roc_auc_tunned)
print("Tuned RF Log Loss: ", logloss_tunned)
print("Tuned RF Recall: ", recall_tunned)
print("Tunned RF Precision: ", precision_tunned)
# Out:
# Tuned RF F1 Score:  0.6941058865937069
# Tuned RF AUC:  0.8086720174610051
# Tuned RF Log Loss:  0.5665354027373546
# Tuned RF Recall:  0.8571428571428571
# Tunned RF Precision:  0.6528784086418127

# %%
from sklearn.metrics import classification_report
print("               Tuned RF classification report")
print(classification_report(y_test, y_pred_tunned))
# Out:
#                Tuned RF classification report
#               precision    recall  f1-score   support
#
#            0       0.79      0.55      0.65      5807
#            1       0.65      0.86      0.74      5782
#
#     accuracy                           0.70     11589
#    macro avg       0.72      0.70      0.69     11589
# weighted avg       0.72      0.70      0.69     11589
